# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
print("sum:",a+b)
# Out:
# sum: 10

# %%
#count the vowels 
x="hellow world"
print(x.lower().count("a")+x.lower().count("e")+x.lower().count("i")+x.lower().count("o")+x.lower().count("u"))
# Out:
# 3
